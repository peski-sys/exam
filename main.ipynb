# %% [markdown]
# ## Saugat Khanal
# ## Bsc. (Hons) Computing
# ## ksaugat24@tbc.edu.np
# ## I am Submitting Exam Paper 2

# %% [markdown]
# # My Programming Work Style
#
# ## Environment & Tools
# I work best in a **quiet, well-lit space** with my laptop. My preferred tools include *Visual Studio Code* for editing and Git for version control.
#
# ## Key Preferences
# - **Language**: Python for easy syntax and quick development
# - **Framework**: I mostly use python for backend microservices outside of college work.
# - **Database**: PostgreSQL
#
# ## Approach
# I believe in ***clean, readable code*** and follow **test-driven development**. Breaking problems into smaller, manageable tasks helps me maintain focus and productivity.
#
# ## Conclusion
# Combining the right *environment*, **proper tools**, and a structured *methodology* enables me to write efficient, maintainable code.

# %%
# Exam Mark Pass/Fail Checker
mark = int(input("Enter your exam mark: "))

if mark >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
